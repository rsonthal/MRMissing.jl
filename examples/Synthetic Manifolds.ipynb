# %% [markdown]
# # Visual results on Synthetic Manifolds

# %% [markdown]
# First let us define the snippets of code that generate our 6 different synthetic manifolds.

# %%
function sigmoid(x)
    return 1/(1+exp(-x))
end

function gendata(N,k)
    if k == 1
        return m1(N)
    elseif k == 2
        return m2(N)
    elseif k == 3
        return m3(N)
    elseif k == 4
        return m4(N)
    elseif k == 5
        return m5(N)
    else
        return m6(N)
    end
end

function m1(N)
    return cos.(rand(N,2)*randn(2,30))
end

function m2(N)
    return cos.(sigmoid.(rand(N,2)*randn(2,30))*rand(30,300))
end

function m3(N)
    x = randn(N)-1
    y = randn(N)-1
    z = exp.(-(sqrt.(x.^2+y.^2)))
    return [x y z]
end

function m4(N)
    x = 2*rand(N)-1
    y = 2*rand(N)-1
    z = 20*exp.(-(x.^2+y.^2))
    return [x y z]
end

function m5(N)
    theta = 2*pi*rand(n)
    phi = pi*rand(n)
    x = sin.(phi) .* cos.(theta)
    y = sin.(phi).* sin.(theta)
    z = cos.(phi)
    return [x y z]
end

function m6(N)
     u = 4*pi*rand(N)
    v = 0.5*u
    x = (3 + cos.(u)).*cos.(v)
    y = (3 + cos.(u)).*sin.(v)
    z = sin.(u)
    return [x y z]
end
# Out:
# m6 (generic function with 1 method)

# %% [markdown]
# Now let us look at the following interactive widget to see how MR-Missing performs. To do tis pick the manifold tat we want to use. The code will then generate 2000 data points on the manfiold. It will then compute a 2 dimensional representation usiong Isomap. Then it will throw away 40% of the data then compute the 2 dimensional representation using MR-Missing.

# %%
using Interact, MR, Plots
plotly()

@manipulate for Manifold in [5]
    n = 2000
    f = 0.4
    
    S = gendata(n,5)
    A = copy(S)
    Q = (rand(size(S)) .> f).^2

    X = Isomap(S,30,2)
    Dmin = MR_Missing(A,Q,30)
    Dmani = MR.apsp(Dmin)
    Xm = mds(Dmani,2)

    
    p = sortperm(X[:,1])
    
    P3 = X[p,:]
    P2 = Xm[p,:]
    
    im1 = scatter(P3[1:400,1], P3[1:400,2])
    im1 = scatter!(P3[401:800,1], P3[401:800,2])
    im1 = scatter!(P3[801:1200,1], P3[801:1200,2])
    im1 = scatter!(P3[1201:1600,1], P3[1201:1600,2])
    im1 = scatter!(P3[1601:end,1], P3[1601:end,2], title = "Full Data")
    
    im2 = scatter(P2[1:400,1], P2[1:400,2])
    im2 = scatter!(P2[401:800,1], P2[401:800,2])
    im2 = scatter!(P2[801:1200,1], P2[801:1200,2])
    im2 = scatter!(P2[1201:1600,1], P2[1201:1600,2])
    im2 = scatter!(P2[1601:end,1], P2[1601:end,2], title = "Missing Data")
    
    p = [im1,im2]
    plot(p...,layout=2)
end
# Out:
# Interact.Options{:ToggleButtons,Int64}(55: "input-18" = 5 Int64 , "Manifold", 5, "5", 1, Interact.OptionDict(DataStructures.OrderedDict("5"=>5), Dict(5=>"5")), Any[], Any[], true, "horizontal", true)
# <script src="file:///Users/rishi/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="0037dfee-cfb3-4373-96cf-d48ee1f8dec6" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('0037dfee-cfb3-4373-96cf-d48ee1f8dec6');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[-1.4289716879513314,-1.428729646107133,-1.4286366637306263,-1.4284204565074905,-1.42823437198502,-1.4281786047435718,-1.428075862053316,-1.4280694356596324,-1.42795762464286,-1.4279494272851465,-1.4279411485215114,-1.4278618285165745,-1.4278265493279971,-1.4277901738927667,-1.4277870046835817,-1.4277026106790147,-1.4273908972720235,-1.4272710656444492,-1.4270469923007516,-1.427001358256306,-1.4258263463007577,-1.4253107442497372,-1.425218458517197,-1.4247129540889436,-1.4233161098391625,-1.4230149155272616,-1.4224703280992428,-1.4220973717048386,-1.4217949161940706,-1.4215763753720048,-1.421395935903621,-1.4211280732370477,-1.4209217166806956,-1.4199353533324823,-1.4198806262862824,-1.4198200751822283,-1.419608895796047,-1.4196030823219847,-1.418633048839523,-1.4185845370491201,-1.4181949410537873,-1.4179785890960983,-1.4176970231564985,-1.4176755734965654,-1.4173313365806661,-1.4172934071540988,-1.4172093756749093,-1.41712481240522,-1.4165961268369065,-1.4162572956272144,-1.416213724558297,-1.4159455116165593,-1.4156616058025637,-1.4146341365967188,-1.4144415444097194,-1.4134820943371793,-1.4131880141929223,-1.412990699043139,-1.4126540669665857,-1.4125186080371492,-1.412434821168734,-1.4121761464314468,-1.4118205620120359,-1.4118022376158164,-1.4115156591944618,-1.4114641910569854,-1.4112672363294325,-1.411136581382602,-1.4109118754381649,-1.4108581397351407,-1.4102705958588795,-1.4099935897503,-1.4093660579297826,-1.4092356554110899,-1.408680900775309,-1.407743380140366,-1.4074470709137104,-1.4067168872220697,-1.4059093913781127,-1.4058959597038092,-1.4051245560258028,-1.405122944351388,-1.4039926365383322,-1.4036431060968677,-1.4035989917469822,-1.4034346361188341,-1.4032844816151548,-1.4030293910724179,-1.4029343599810506,-1.4026494089959696,-1.402041888855991,-1.4019349600647264,-1.4019184409506955,-1.401759614649091,-1.4016192442214275,-1.401239947305688,-1.400906894122946 ...

# %%
S = gendata(2000,5)
scatter(S[:,1], S[:,2], S[:,3])
# Out:
# <script src="file:///Users/rishi/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="5bf25874-b760-45b9-990e-5ad3aaae7bb2" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('5bf25874-b760-45b9-990e-5ad3aaae7bb2');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
function genData6(n)
    A = gendata(n,4)
    B = randn(3,30)
    return cos.(A*B)
end
# Out:
# genData6 (generic function with 1 method)
